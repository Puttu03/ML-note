# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Linear Regression.csv")

# %%
data
# Out:
#     Years of Experience  Salary (USD)
# 0                     1         97121
# 1                     2         65920
# 2                     2         78555
# 3                     3        102409
# 4                     3         53483
# 5                     4         53897
# 6                     5        101211
# 7                     6        110077
# 8                     7         33890
# 9                     7         38792
# 10                    8         98148
# 11                    8         40627
# 12                   10         96557
# 13                   11         73001
# 14                   11        106552
# 15                   11        117313
# 16                   12         99479
# 17                   12         47159
# 18                   12         39692
# 19                   12        119475
# 20                   15        110038
# 21                   15        108953
# 22                   15         82995
# 23                   16        107189
# 24                   17         49457
# 25                   19        103969
# 26                   19         70757
# 27                   20         71606
# 28                   20         75758

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years of Experience  29 non-null     int64
#  1   Salary (USD)         29 non-null     int64
# dtypes: int64(2)
# memory usage: 596.0 bytes

# %%
X = data.iloc[:, :-1].values

# %%
Y = data.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1],
#        [ 2],
#        [ 2],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 8],
#        [10],
#        [11],
#        [11],
#        [11],
#        [12],
#        [12],
#        [12],
#        [12],
#        [15],
#        [15],
#        [15],
#        [16],
#        [17],
#        [19],
#        [19],
#        [20],
#        [20]], dtype=int64)

# %%
Y
# Out:
# array([ 97121,  65920,  78555, 102409,  53483,  53897, 101211, 110077,
#         33890,  38792,  98148,  40627,  96557,  73001, 106552, 117313,
#         99479,  47159,  39692, 119475, 110038, 108953,  82995, 107189,
#         49457, 103969,  70757,  71606,  75758], dtype=int64)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=1/3,random_state=0)

# %%
X_train
# Out:
# array([[ 7],
#        [12],
#        [15],
#        [12],
#        [ 2],
#        [ 8],
#        [20],
#        [ 5],
#        [ 3],
#        [12],
#        [12],
#        [ 7],
#        [ 6],
#        [17],
#        [ 3],
#        [ 1],
#        [15],
#        [11],
#        [10]], dtype=int64)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[ 2],
#        [15],
#        [16],
#        [11],
#        [ 8],
#        [19],
#        [20],
#        [19],
#        [ 4],
#        [11]], dtype=int64)

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([82225.75751995, 79960.00675261, 79785.71823204, 80657.16083487,
#        81180.02639656, 79262.85267035, 79088.56414979, 79262.85267035,
#        81877.18047882, 80657.16083487])

# %%
reg.predict(X_train)
# Out:
# array([81354.31491713, 80482.8723143 , 79960.00675261, 80482.8723143 ,
#        82225.75751995, 81180.02639656, 79088.56414979, 81702.89195826,
#        82051.46899939, 80482.8723143 , 80482.8723143 , 81354.31491713,
#        81528.60343769, 79611.42971148, 82051.46899939, 82400.04604052,
#        79960.00675261, 80657.16083487, 80831.44935543])

# %%
plt.scatter(X_train,Y_train, color = 'red')
plt.plot(X_train,reg.predict(X_train), color = 'Blue')

# %%
plt.scatter(X_test,Y_test, color = 'red')
plt.plot(X_test,Y_pred,color = 'Blue')
